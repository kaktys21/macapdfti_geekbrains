# %%
import requests
import json
import os
import cv2
import numpy as np

# %% [markdown]
# ##1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле

# %%
git_url = 'https://api.github.com'
user = 'kaktys21'
folder_path = r'/content/drive/MyDrive/BG_macapdfti/lesson-1'

# %%
user_repos = requests.get(f'{url}/users/{user}/repos').json()
print(*(i['name'] for i in user_repos), sep='\n')
# Out:
# diploma-everything
# mySQL_geekbrains
# python-for-DataScience_geekbrains
# python-for-DataScience_geekbrains2
# python_geekbrains
# rucorpora-test
# ruscorpora-parse

# %%
# with open(os.path.join(folder_path, 'git_api.json'), 'w', encoding='utf-8') as out_file:
#  json.dump(user_repos, out_file)

# %% [markdown]
# ##2. Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
kitty_url = 'https://api.thecatapi.com/v1/images/search'
headers = {'x-api-key' : '4ecdb206-3f40-4c61-b619-371c7dba998f'}

# %%
url_kitty = requests.request('get', kitty_url, headers=headers).json()

# %%
#with open(os.path.join(folder_path, 'kitty_api.json'), 'w', encoding='utf-8') as out_file:
#  json.dump(url_kitty, out_file)

# %%
resp = requests.get(url_kitty[0]['url'], stream=True).raw
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333 at 0x7F4E325F7E10>
